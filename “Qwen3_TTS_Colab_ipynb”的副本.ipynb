# %% [markdown]
# <a href="https://colab.research.google.com/github/wokaowo/novel-workflow/blob/main/%E2%80%9CQwen3_TTS_Colab_ipynb%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 🏷️ **Credits & License**
#
# * 🔗 [Qwen3-TTS GitHub Repository](https://github.com/QwenLM/Qwen3-TTS)
# * 🤗 [Qwen3-TTS on Hugging Face](https://huggingface.co/collections/Qwen/qwen3-tts)
# * 📄 **License**: Provided under the [Apache License 2.0](https://github.com/QwenLM/Qwen3-TTS?tab=Apache-2.0-1-ov-file)
# * 🤗 [Try Qwen3-TTS on HuggingFace Space](https://huggingface.co/spaces/Qwen/Qwen3-TTS)
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install Qwen3-TTS
# %cd /content/
# !rm -rf /content/Qwen3-TTS-Colab
# !git clone https://github.com/NeuralFalconYT/Qwen3-TTS-Colab.git
# !git clone https://github.com/QwenLM/Qwen3-TTS.git
# %cd Qwen3-TTS
# !pip install -e .
# !pip install faster-whisper==1.1.1
# !pip install ctranslate2==4.5.0
# !pip install pysrt
# !pip install sentencex
from IPython.display import Audio,display
from IPython.display import clear_output
import time
clear_output()

display(Audio("https://raw.githubusercontent.com/NeuralFalconYT/Useful-Function/refs/heads/main/audio/warning.mp3", autoplay=True))
time.sleep(6)
clear_output()
# time.sleep(5)
# import os
# os.kill(os.getpid(), 9)

# %%
# %cd /content/Qwen3-TTS-Colab
# !python app.py --share --debug
# Out:
# /content/Qwen3-TTS-Colab
# 2026-03-17 16:12:40.852740: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773763960.875977    1695 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773763960.883650    1695 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773763960.903476    1695 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773763960.903524    1695 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773763960.903528    1695 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773763960.903534    1695 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-17 16:12:40.908739: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ********
# Warning: flash-attn is not installed. Will only run the manual PyTorch version. Please install flash-attn for faster inference.
# ********
#
# /bin/sh: 1: sox: not found
# WARNING:sox:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.
#
# /content/Qwen3-TTS-Colab/app.py:354: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="Qwen3-TTS Demo") as demo:
# /content/Qwen3-TTS-Colab/app.py:354: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="Qwen3-TTS Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://b35ed58f9ada7afb62.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Starting transcription for: /tmp/gradio/2064731479edc0cda447380575fd5f77040b0371255cede49fe6af1bb820d9cc/54779-401422082525858c89286a4100-1764522729072.mp3
# config.json: 2.26kB [00:00, 11.1MB/s]
# vocabulary.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 222kB/s]
#
# vocabulary.json: 1.07MB [00:00, 15.5MB/s]
# tokenizer.json: 2.71MB [00:00, 50.4MB/s]
# model.bin: 100% 1.62G/1.62G [00:12<00:00, 128MB/s]
# Starting transcription for: /tmp/gradio/2064731479edc0cda447380575fd5f77040b0371255cede49fe6af1bb820d9cc/54779-401422082525858c89286a4100-1764522729072.mp3
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# config.json: 4.49kB [00:00, 13.1MB/s]
#
# README.md: 0.00B [00:00, ?B/s]
#
# generation_config.json: 100% 245/245 [00:00<00:00, 1.98MB/s]
# README.md: 57.8kB [00:00, 14.3MB/s]
#
# preprocessor_config.json:   0% 0.00/127 [00:00<?, ?B/s]
#
# preprocessor_config.json: 100% 127/127 [00:00<00:00, 40.1kB/s]
#
# config.json: 2.34kB [00:00, 8.06MB/s]
#
# merges.txt: 1.67MB [00:00, 39.0MB/s]
#
#
# preprocessor_config.json: 100% 234/234 [00:00<00:00, 2.47MB/s]
#
#
# configuration.json: 100% 76.0/76.0 [00:00<00:00, 716kB/s]
#
#
# tokenizer_config.json: 7.34kB [00:00, 42.1MB/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
#
#
# vocab.json: 0.00B [00:00, ?B/s]
#
#
#
# .gitattributes: 1.52kB [00:00, 6.11MB/s]
# vocab.json: 2.78MB [00:00, 48.3MB/s]
#
# model.safetensors:   0% 0.00/3.86G [00:00<?, ?B/s]
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:00<?, ?B/s]
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:00<?, ?B/s]
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:00<?, ?B/s]
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:01<?, ?B/s]
#
# speech_tokenizer/model.safetensors:  10% 67.1M/682M [00:01<00:01, 335MB/s]
# model.safetensors:   0% 0.00/3.86G [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:01<?, ?B/s]
#
# speech_tokenizer/model.safetensors:  20% 134M/682M [00:01<00:04, 121MB/s]
# model.safetensors:   0% 0.00/3.86G [00:02<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:02<?, ?B/s]
#
# speech_tokenizer/model.safetensors:  29% 201M/682M [00:02<00:03, 139MB/s]
# model.safetensors:   0% 0.00/3.86G [00:02<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:02<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:02<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:03<?, ?B/s]
#
# speech_tokenizer/model.safetensors:  39% 268M/682M [00:03<00:03, 110MB/s]
# model.safetensors:   0% 0.00/3.86G [00:03<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:03<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:03<?, ?B/s]
#
# speech_tokenizer/model.safetensors:  49% 335M/682M [00:03<00:03, 111MB/s]
# model.safetensors:   0% 0.00/3.86G [00:03<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:04<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:04<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:04<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:04<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:04<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:05<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:05<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:05<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:05<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:05<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:06<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:06<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:07<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:09<?, ?B/s]
#
# speech_tokenizer/model.safetensors:  69% 470M/682M [00:09<00:05, 40.2MB/s]
#
# speech_tokenizer/model.safetensors:  93% 632M/682M [00:11<00:00, 51.1MB/s]
#
# speech_tokenizer/model.safetensors: 100% 682M/682M [00:11<00:00, 58.6MB/s]
#
# model.safetensors:   0% 0.00/3.86G [00:18<?, ?B/s]
# model.safetensors:  42% 1.61G/3.86G [00:18<00:00, 8.49GB/s]
# model.safetensors:  47% 1.81G/3.86G [00:32<00:00, 8.49GB/s]
# model.safetensors:  47% 1.81G/3.86G [00:32<00:20, 98.9MB/s]
# model.safetensors:  47% 1.81G/3.86G [00:47<00:20, 98.9MB/s]
# model.safetensors:  70% 2.68G/3.86G [00:51<00:18, 62.5MB/s]
# model.safetensors:  70% 2.68G/3.86G [01:02<00:18, 62.5MB/s]
# model.safetensors: 100% 3.86G/3.86G [01:27<00:00, 44.3MB/s]
# Fetching 13 files: 100% 13/13 [01:27<00:00,  6.71s/it]
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Stitching 1 audio files...
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Stitching 1 audio files...
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Stitching 1 audio files...
